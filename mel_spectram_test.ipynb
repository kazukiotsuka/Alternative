# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append('../../')
import IPython.display as ipd
import librosa
import librosa.display
import numpy as np
from tools.libaudio.utils import load
from tools.libaudio.feature import melspectram, melspectrogram, stft
from tools.libaudio.waves import sin_wave
from tools.libaudio.display import show_spec, show_mel
from mlutils.utils import plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sr, seq = 24000, 10000
wave = sin_wave(100, seq, sr) + sin_wave(1000, seq, sr) + sin_wave(4000, seq, sr)

# %%
plot(wave)

# %%
spec = _stft(wave)

# %%
plot(np.abs(spec))

# %%
show_spec(spec)

# %%
mel = melspectram(np.array(wave))  # type 1

# %%
show_mel(mel)

# %%
plot(mel)

# %%
mel2 = melspectrogram(np.array(wave))  # type 2

# %%
plot(mel2)

# %%
show_mel(mel2)

# %%
mel2.shape  # (freq_bin, sample_len / hop_size)
# Out:
# (128, 34)

# %%
wav = load('/diskB/6/Datasets/VoiceData/jsut_ver1.1/basic5000/wav/BASIC5000_0051.wav', sample_rate=24000)
plot(wav)

# %%
wav.shape
# Out:
# (86880,)

# %%
spectram = stft(wav)
plot(np.abs(spectram))

# %%
show_spec(spectram)

# %%
mel3 = melspectram(wav)  # type 1
plot(mel3)

# %%
show_mel(mel3)

# %%
mel4 = melspectrogram(wav)  # type 2

# %%
plot(mel4)

# %%
show_mel(mel4)

# %%
mel4.shape
# Out:
# (128, 290)

# %%
sample_len = len(wav)
hop_len = 300
sample_len / hop_len  # = time frame ~= mel4.shape[1]
# Out:
# 289.6

# %%
sample_rate = 24000
frame_hop = 12.5
sample_rate / 1000 * frame_hop  # = hop_length
# Out:
# 300.0
